# %%
import numpy as np
import matplotlib.pyplot as plt
import iisignature as iis

# %%
def lead_tensor_1(mv_time_series):
    N=mv_time_series.shape[1]
    sig=iis.sig(mv_time_series,3)
    l=N+N*N
    S=sig[l:].reshape(N,N,N)
    T=(S-S.transpose((0,2,1))+S.transpose((2,0,1))-S.transpose((2,1,0))+S.transpose((1,2,0))-S.transpose((1,0,2)))/6
    return T

# %%
def lead_matrix_1(mv_time_series):
    N=mv_time_series.shape[1]
    sig=iis.sig(mv_time_series,2)
    S=sig[N:].reshape(N,N)
    L=(S-S.T)/2
    return L

# %%
# HELIX

t=np.linspace(0,2*np.pi,400)
x=np.cos(t)
y=np.sin(t)
z=t
u=np.zeros((400,3))
u[:,0]=x
u[:,1]=y
u[:,2]=z

T=lead_tensor_1(u)
print(T[0,1,2])

fig = plt.figure()
 
# syntax for 3-D projection
ax = plt.axes(projection ='3d')
 
# defining all 3 axis

# plotting
ax.plot3D(x, y, z, 'green')
ax.set_title("HELIX")
plt.show()
# Out:
# 6.579464331961812

# %%
# PLANE CURVE

t=np.linspace(0,2*np.pi,400)
x=1-2*np.cos(t)
y=np.sin(t)
z=np.cos(t)
u=np.zeros((400,3))
u[:,0]=x
u[:,1]=y
u[:,2]=z
T=lead_tensor_1(u)
print(T[0,1,2])

fig = plt.figure()
 
# syntax for 3-D projection
ax = plt.axes(projection ='3d')
 
# defining all 3 axis

# plotting
ax.plot3D(x, y, z, 'green')
ax.set_title("PLANE CURVE")
plt.show()
# Out:
# 1.3322676295501878e-15

# %%
# CUBICAL STUFF

t=np.linspace(0,3,400)
x=t*t*t+1
y=t*t*t+t
z=t*t+1
u=np.zeros((400,3))
u[:,0]=x
u[:,1]=y
u[:,2]=z
T=lead_tensor_1(u)
print(T[0,1,2])

fig = plt.figure()
 
# syntax for 3-D projection
ax = plt.axes(projection ='3d')
 
# plotting
ax.plot3D(x, y, z, 'green')
ax.set_title("CUBICAL STUFF")
plt.show()
# Out:
# 4.049872802946292

# %%
# STRANGE HELIX

t=np.linspace(0,2*np.pi,400)
x=2*np.sqrt(2)*t-np.sin(t)
y=2*np.sqrt(2)*np.sin(t)+t
z=3*np.cos(t)
u=np.zeros((400,3))
u[:,0]=x
u[:,1]=y
u[:,2]=z
T=lead_tensor_1(u)
print(T[0,1,2])

fig = plt.figure()
 
# syntax for 3-D projection
ax = plt.axes(projection ='3d')
 
# plotting
ax.plot3D(x, y, z, 'green')
ax.set_title("STRANGE HELIX")
plt.show()
# Out:
# -177.64553696296886

# %%
# SADDLE

t=np.linspace(0,2*np.pi,400)
x=np.cos(t)
y=np.sin(t)
z=np.cos(2*t)
u=np.zeros((400,3))
u[:,0]=x
u[:,1]=y
u[:,2]=z
T=lead_tensor_1(u)
print(T[0,1,2])

fig = plt.figure()
 
# syntax for 3-D projection
ax = plt.axes(projection ='3d')
 
# plotting
ax.plot3D(x, y, z, 'green')
ax.set_title("SADDLE")
plt.show()
# Out:
# -1.3322676295501878e-15

# %%
# SIMIL HELIX

t=np.linspace(0,4*np.pi,400)
x=t-3*np.sin(t)
y=1-np.cos(t)
z=t
u=np.zeros((400,3))
u[:,0]=x
u[:,1]=y
u[:,2]=z
T=lead_tensor_1(u)
print(T[0,1,2])

fig = plt.figure()
 
# syntax for 3-D projection
ax = plt.axes(projection ='3d')
 
# defining all 3 axis

# plotting
ax.plot3D(x, y, z, 'green')
ax.set_title("SIMIL HELIX")
plt.show()
# Out:
# -78.94378279353968

# %%
# EXPONENTIAL ZIGZAG

t=np.linspace(0,6*np.pi,400)
x=2*np.exp(np.sin(t))
y=np.exp(np.cos(0.5*t))
z=np.sqrt(t)
u=np.zeros((400,3))
u[:,0]=x
u[:,1]=y
u[:,2]=z
T=lead_tensor_1(u)
print(T[0,1,2])

fig = plt.figure()
 
# syntax for 3-D projection
ax = plt.axes(projection ='3d')
 
# defining all 3 axis

# plotting
ax.plot3D(x, y, z, 'green')
ax.set_title("EXPONENTIAL ZIGZAG")
plt.show()
# Out:
# -7.870663380858115

# %%
# HELIX

t=np.linspace(0,1,400)
x=np.cos(2*np.pi*t)
y=np.sin(2*np.pi*t)
z=t
u=np.zeros((400,3))
u[:,0]=x
u[:,1]=y
u[:,2]=z

T=lead_tensor_1(u)
print(T[0,1,2])

fig = plt.figure()
 
# syntax for 3-D projection
ax = plt.axes(projection ='3d')
 
# defining all 3 axis

# plotting
ax.plot3D(x, y, z, 'green')
ax.set_title("HELIX")
plt.show()
# Out:
# 1.0471542713285362

# %%
# HELIX

t=np.linspace(0,1,400)
x=np.ones(400)
y=np.zeros(400)
z=1-t
u=np.zeros((400,3))
u[:,0]=x
u[:,1]=y
u[:,2]=z

T=lead_tensor_1(u)
print(T[0,1,2])

fig = plt.figure()
 
# syntax for 3-D projection
ax = plt.axes(projection ='3d')
 
# defining all 3 axis

# plotting
ax.plot3D(x, y, z, 'green')
ax.set_title("STRAIGHT LINE")
plt.show()
# Out:
# 0.0

# %%
# HELIX

t1=np.linspace(0,1,400)
x1=np.cos(2*np.pi*t)
y1=np.sin(2*np.pi*t)
z1=t1

t=np.linspace(0,1,400)
x2=np.ones(400)
y2=np.zeros(400)
z2=1-t

x=np.concatenate((x1,x2))
y=np.concatenate((y1,y2))
z=np.concatenate((z1,z2))


u=np.zeros((800,3))
u[:,0]=x
u[:,1]=y
u[:,2]=z




T=lead_tensor_1(u)
print(T[0,1,2])

fig = plt.figure()
 
# syntax for 3-D projection
ax = plt.axes(projection ='3d')
 
# defining all 3 axis

# plotting
ax.plot3D(x, y, z, 'green')
ax.set_title("HELIX")
plt.show()
# Out:
# 1.7393494052460785e-15

# %%
# HELIX

t=np.linspace(0,1,400)
x=np.cos(2*np.pi*t)
y=np.sin(2*np.pi*t)
z=t
u=np.zeros((400,3))
u[:,0]=x
u[:,1]=y
u[:,2]=z

T=lead_tensor_1(u)
print(T[0,1,2])

L=lead_matrix_1(u)
print(L)

fig = plt.figure()
 
# syntax for 3-D projection
ax = plt.axes(projection ='3d')
 
# defining all 3 axis

# plotting
ax.plot3D(x, y, z, 'green')
ax.set_title("HELIX")
plt.show()
# Out:
# 1.0471542713285362
# [[ 0.00000000e+00  3.14146281e+00 -1.00000000e+00]
#  [-3.14146281e+00  0.00000000e+00 -9.95077366e-17]
#  [ 1.00000000e+00  9.95077366e-17  0.00000000e+00]]
